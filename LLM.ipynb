# %%
! pip install genai langchain langchain_google_genai
# Out:
# Collecting genai
#   Using cached genai-2.1.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting langchain
#   Using cached langchain-0.3.26-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: langchain_google_genai in c:\perflogs\lib\site-packages (2.1.6)
# Requirement already satisfied: ipython<9.0.0,>=8.10.0 in c:\perflogs\lib\site-packages (from genai) (8.31.0)
# Collecting openai<0.28.0,>=0.27.0 (from genai)
#   Using cached openai-0.27.10-py3-none-any.whl.metadata (13 kB)
# Collecting tabulate<0.10.0,>=0.9.0 (from genai)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting tiktoken<0.4.0,>=0.3.2 (from genai)
#   Using cached tiktoken-0.3.3.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\perflogs\lib\site-packages (from langchain) (0.3.68)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Using cached langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langsmith>=0.1.17 in c:\perflogs\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\perflogs\lib\site-packages (from langchain) (2.10.6)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Using cached sqlalchemy-2.0.41-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\perflogs\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\perflogs\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\perflogs\lib\site-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in c:\perflogs\lib\site-packages (from langchain_google_genai) (0.6.18)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\perflogs\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.24.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\perflogs\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\perflogs\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\perflogs\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (5.29.3)
# Requirement already satisfied: colorama in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (0.4.6)
# Requirement already satisfied: decorator in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (2.19.1)
# Requirement already satisfied: stack_data in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\perflogs\lib\site-packages (from ipython<9.0.0,>=8.10.0->genai) (5.14.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\perflogs\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\perflogs\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\perflogs\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\perflogs\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\perflogs\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\perflogs\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\perflogs\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\perflogs\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: tqdm in c:\perflogs\lib\site-packages (from openai<0.28.0,>=0.27.0->genai) (4.66.5)
# Requirement already satisfied: aiohttp in c:\perflogs\lib\site-packages (from openai<0.28.0,>=0.27.0->genai) (3.11.18)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\perflogs\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\perflogs\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\perflogs\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\perflogs\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\perflogs\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\perflogs\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet>=1 in c:\perflogs\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\perflogs\lib\site-packages (from tiktoken<0.4.0,>=0.3.2->genai) (2024.11.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\perflogs\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.69.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\perflogs\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\perflogs\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\perflogs\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\perflogs\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\perflogs\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (4.9)
# Requirement already satisfied: anyio in c:\perflogs\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\perflogs\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\perflogs\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\perflogs\lib\site-packages (from jedi>=0.16->ipython<9.0.0,>=8.10.0->genai) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\perflogs\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (2.1)
# Requirement already satisfied: wcwidth in c:\perflogs\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<9.0.0,>=8.10.0->genai) (0.2.13)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\perflogs\lib\site-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\perflogs\lib\site-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\perflogs\lib\site-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\perflogs\lib\site-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\perflogs\lib\site-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\perflogs\lib\site-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\perflogs\lib\site-packages (from aiohttp->openai<0.28.0,>=0.27.0->genai) (1.20.0)
# Requirement already satisfied: executing>=1.2.0 in c:\perflogs\lib\site-packages (from stack_data->ipython<9.0.0,>=8.10.0->genai) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\perflogs\lib\site-packages (from stack_data->ipython<9.0.0,>=8.10.0->genai) (3.0.0)
# Requirement already satisfied: pure_eval in c:\perflogs\lib\site-packages (from stack_data->ipython<9.0.0,>=8.10.0->genai) (0.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\perflogs\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\perflogs\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Using cached genai-2.1.0-py3-none-any.whl (16 kB)
# Using cached langchain-0.3.26-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Using cached openai-0.27.10-py3-none-any.whl (76 kB)
# Using cached sqlalchemy-2.0.41-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Building wheels for collected packages: tiktoken
#   Building wheel for tiktoken (pyproject.toml): started
#   Building wheel for tiktoken (pyproject.toml): finished with status 'error'
# Failed to build tiktoken
#   error: subprocess-exited-with-error
#
#   × Building wheel for tiktoken (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [49 lines of output]
#       C:\Users\阿群\AppData\Local\Temp\pip-build-env-rixuudpo\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
#               Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#               By 2026-Feb-18, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         corresp(dist, value, root_dir)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\core.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\load.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\model.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\registry.py -> build\lib.win-amd64-cpython-312\tiktoken
#       copying tiktoken\__init__.py -> build\lib.win-amd64-cpython-312\tiktoken
#       creating build\lib.win-amd64-cpython-312\tiktoken_ext
#       copying tiktoken_ext\openai_public.py -> build\lib.win-amd64-cpython-312\tiktoken_ext
#       running egg_info
#       writing tiktoken.egg-info\PKG-INFO
#       writing dependency_links to tiktoken.egg-info\dependency_links.txt
#       writing requirements to tiktoken.egg-info\requires.txt
#       writing top-level names to tiktoken.egg-info\top_level.txt
#       reading manifest file 'tiktoken.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching 'Makefile'
#       adding license file 'LICENSE'
#       writing manifest file 'tiktoken.egg-info\SOURCES.txt'
#       copying tiktoken\py.typed -> build\lib.win-amd64-cpython-312\tiktoken
#       running build_ext
#       running build_rust
#       error: can't find Rust compiler
#
#       If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#       To update pip, run:
#
#           pip install --upgrade pip
#
#       and then retry package installation.
#
#       If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tiktoken
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tiktoken)

# %%
API_KEY = "AIzaSyBVbOFbtk4-gIcVqFJThSJK9OTDtNhjHS0"

# %%
! pip install langchain_google_genai
# Out:
# Requirement already satisfied: langchain_google_genai in c:\perflogs\lib\site-packages (2.1.6)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\perflogs\lib\site-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in c:\perflogs\lib\site-packages (from langchain_google_genai) (0.6.18)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.66 in c:\perflogs\lib\site-packages (from langchain_google_genai) (0.3.68)
# Requirement already satisfied: pydantic<3,>=2 in c:\perflogs\lib\site-packages (from langchain_google_genai) (2.10.6)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\perflogs\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.24.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\perflogs\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\perflogs\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\perflogs\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (5.29.3)
# Requirement already satisfied: langsmith>=0.3.45 in c:\perflogs\lib\site-packages (from langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (0.4.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\perflogs\lib\site-packages (from langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\perflogs\lib\site-packages (from langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\perflogs\lib\site-packages (from langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\perflogs\lib\site-packages (from langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\perflogs\lib\site-packages (from langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\perflogs\lib\site-packages (from pydantic<3,>=2->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\perflogs\lib\site-packages (from pydantic<3,>=2->langchain_google_genai) (2.27.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\perflogs\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.69.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\perflogs\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\perflogs\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\perflogs\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\perflogs\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\perflogs\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\perflogs\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\perflogs\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\perflogs\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\perflogs\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\perflogs\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\perflogs\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (0.23.0)
# Requirement already satisfied: anyio in c:\perflogs\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (4.9.0)
# Requirement already satisfied: certifi in c:\perflogs\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\perflogs\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (1.0.9)
# Requirement already satisfied: idna in c:\perflogs\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\perflogs\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\perflogs\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\perflogs\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\perflogs\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain_google_genai) (2.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\perflogs\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.66->langchain_google_genai) (1.3.1)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI


llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0,
    timeout=None,
    max_retries=2,
    # other params...
)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[18], line 4
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
# ----> 4 llm = ChatGoogleGenerativeAI(
#       5     model="gemini-2.0-flash",
#       6     temperature=0,
#       7     timeout=None,
#       8     max_retries=2,
#       9     # other params...
#      10 )
#
# File c:\PerfLogs\Lib\site-packages\langchain_google_genai\chat_models.py:1179, in ChatGoogleGenerativeAI.__init__(self, **kwargs)
#    1172         suggestion = (
#    1173             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1174         )
#    1175         logger.warning(
#    1176             f"Unexpected argument '{arg}' "
#    1177             f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    1178         )
# -> 1179 super().__init__(**kwargs)
#
# File c:\PerfLogs\Lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\PerfLogs\Lib\site-packages\langchain_google_genai\chat_models.py:1240, in ChatGoogleGenerativeAI.validate_environment(self)
#    1238         google_api_key = self.google_api_key
#    1239 transport: Optional[str] = self.transport
# -> 1240 self.client = genaix.build_generative_service(
#    1241     credentials=self.credentials,
#    1242     api_key=google_api_key,
#    1243     client_info=client_info,
#    1244     client_options=self.client_options,
#    1245     transport=transport,
#    1246 )
#    1247 self.async_client_running = None
#    1248 return self
#
# File c:\PerfLogs\Lib\site-packages\langchain_google_genai\_genai_extension.py:276, in build_generative_service(credentials, api_key, client_options, client_info, transport)
#     262 def build_generative_service(
#     263     credentials: Optional[credentials.Credentials] = None,
#     264     api_key: Optional[str] = None,
#    (...)
#     267     transport: Optional[str] = None,
#     268 ) -> v1betaGenerativeServiceClient:
#     269     config = _prepare_config(
#     270         credentials=credentials,
#     271         api_key=api_key,
#    (...)
#     274         client_info=client_info,
#     275     )
# --> 276     return v1betaGenerativeServiceClient(**config)
#
# File c:\PerfLogs\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:697, in GenerativeServiceClient.__init__(self, credentials, transport, client_options, client_info)
#     688     transport_init: Union[
#     689         Type[GenerativeServiceTransport],
#     690         Callable[..., GenerativeServiceTransport],
#    (...)
#     694         else cast(Callable[..., GenerativeServiceTransport], transport)
#     695     )
#     696     # initialize with the provided callable or the passed in class
# --> 697     self._transport = transport_init(
#     698         credentials=credentials,
#     699         credentials_file=self._client_options.credentials_file,
#     700         host=self._api_endpoint,
#     701         scopes=self._client_options.scopes,
#     702         client_cert_source_for_mtls=self._client_cert_source,
#     703         quota_project_id=self._client_options.quota_project_id,
#     704         client_info=client_info,
#     705         always_use_jwt_access=True,
#     706         api_audience=self._client_options.api_audience,
#     707     )
#     709 if "async" not in str(self._transport):
#     710     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     711         std_logging.DEBUG
#     712     ):  # pragma: NO COVER
#
# File c:\PerfLogs\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\transports\grpc.py:234, in GenerativeServiceGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     229             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     230                 certificate_chain=cert, private_key=key
#     231             )
#     233 # The base transport sets the host, credentials and scopes
# --> 234 super().__init__(
#     235     host=host,
#     236     credentials=credentials,
#     237     credentials_file=credentials_file,
#     238     scopes=scopes,
#     239     quota_project_id=quota_project_id,
#     240     client_info=client_info,
#     241     always_use_jwt_access=always_use_jwt_access,
#     242     api_audience=api_audience,
#     243 )
#     245 if not self._grpc_channel:
#     246     # initialize with the provided callable or the default channel
#     247     channel_init = channel or type(self).create_channel
#
# File c:\PerfLogs\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\transports\base.py:100, in GenerativeServiceTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      96     credentials, _ = google.auth.load_credentials_from_file(
#      97         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#      98     )
#      99 elif credentials is None and not self._ignore_credentials:
# --> 100     credentials, _ = google.auth.default(
#     101         **scopes_kwargs, quota_project_id=quota_project_id
#     102     )
#     103     # Don't apply audience if the credentials file passed from user.
#     104     if hasattr(credentials, "with_gdch_audience"):
#
# File c:\PerfLogs\Lib\site-packages\google\auth\_default.py:719, in default(scopes, request, quota_project_id, default_scopes)
#     711             _LOGGER.warning(
#     712                 "No project ID could be determined. Consider running "
#     713                 "`gcloud config set project` or setting the %s "
#     714                 "environment variable",
#     715                 environment_vars.PROJECT,
#     716             )
#     717         return credentials, effective_project_id
# --> 719 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
